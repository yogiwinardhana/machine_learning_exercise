# %% [markdown]
# # Decision Forest and Random Forests in Python

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Get the data

# %%
df = pd.read_csv("../00_general_data/kyphosis.csv")
df.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
df['Kyphosis'].unique()
# Out:
# array(['absent', 'present'], dtype=object)

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %%
sns.pairplot(df, hue='Kyphosis', palette='Set1')

# %%
sns.pairplot(df, kind='kde')

# %% [markdown]
# ## Train Test and Split

# %% [markdown]
# split data into train and test data

# %%
from sklearn.model_selection import train_test_split

# %%
# get predictor variables
x = df.drop('Kyphosis', axis=1)

# %%
# get dependent variable
y = df['Kyphosis']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=101)

# %% [markdown]
# ## Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Prediction and Evaluation

# %%
prediction = dtree.predict(X_test)
print(prediction)
# Out:
# ['absent' 'present' 'present' 'absent' 'absent' 'absent' 'absent'
#  'present' 'absent' 'absent' 'absent' 'absent' 'present' 'present'
#  'present' 'absent' 'absent' 'absent' 'absent' 'absent' 'absent' 'absent'
#  'present' 'absent' 'absent']

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#       absent       0.67      0.71      0.69        17
#      present       0.29      0.25      0.27         8
#
#     accuracy                           0.56        25
#    macro avg       0.48      0.48      0.48        25
# weighted avg       0.54      0.56      0.55        25

# %%
print(confusion_matrix(y_test, prediction))
# Out:
# [[12  5]
#  [ 6  2]]

# %% [markdown]
# ## Tree Visualization

# %%
from IPython.display import Image  
from six import StringIO  
from sklearn.tree import export_graphviz
import pydot

# %%
features = list(df.columns[1:])
features
# Out:
# ['Age', 'Number', 'Start']

# %% [markdown]
# dot_data = StringIO()
# export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True)
#
# graph = pydot.graph_from_dot_data(dot_data.getvalue())
# Image(graph[0].create_png())

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc  = RandomForestClassifier(n_estimators=98)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=98)

# %%
rfc_prediction = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test, rfc_pred)
# Out:
#   Input In [45]
#     print(confusion_matrix(y_test, rfc_pred)
#                                             ^
# SyntaxError: unexpected EOF while parsing

# %%
print(classification_report(y_test, rfc_pred))

# %% [markdown]
# ## Learn more
# https://towardsdatascience.com/enchanted-random-forest-b08d418cb411
